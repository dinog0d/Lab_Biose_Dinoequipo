# %% [markdown]
# <a href="https://colab.research.google.com/github/dinog0d/Lab_Biose_Dinoequipo/blob/main/Practica_1/P1_Python_AnnyElizabethRaigoza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# @title **PRACTICA 1 BIOSEÑALES Y SISTEMAS, ANNY RAIGOZA 1000190629**
from IPython.display import Image
Image("/content/drive/MyDrive/Imagen/Escudo-UdeA.svg.png")

# %% [markdown]
# ***ANNY ELIZABETH RAIGOZA RESTREPO 1000190629***
# ## ***PROCEDIMIENTO***
#
# a. **Cree los siguientes pares de vectores: a=[67.1,1,-0.3,5.2,-6], b=[1,3,2.2,5.1,1]**

# %%
import numpy as np
from numpy import pi
import matplotlib.pyplot as plt
import pandas as pd

a = np.array([67.1,1,-0.3,5.2,-6])
b = np.array([1,3,2.2,5.1,1])

# %% [markdown]
# b. **Implemente la multiplicación escalar de a.b ¿Qué se debe realizar para poder multiplicar vectores?**
#
# Respuesta = Con el objetivo de obtener un número escalar como resultado de la multiplicación de vectores se deben cumplir los siguientes requerimientos.
#
#
# 1.   Los vectores deben tener igual longitud, es decir, mismo número de elementos.
# 2.   La multiplicación se debe realizar por posiciones, en otras palabras, el primer elemento (posición 1) del primer vector, debe multiplicarse con el primer elemento (en la posición 1) del segundo vector y continuar así hasta recorrer todos los componentes de los vectores.
# 3. Una vez realizada la multiplicación en cada posición, se procederá a sumar todos los resltados, logrando obtener un escalar.
#
# Para este caso se implementará la función de **np.dot** que realiza este proceso.

# %%
mult_escalar = np.dot(a,b)
print("La multiplicación escalar de a y b es: ",mult_escalar)
# Out:
# La multiplicación escalar de a y b es:  89.96

# %% [markdown]
# c. **Implemente la multiplicación punto a punto de a.b**
#
# Es importante destacar que la multiplicación punto a punto en Python, consiste en realizar el producto por posición de cada elemento de vectores SIN SUMAR los resultados de cada operación, es decir, se basa es realizar únicamente el punto 2 del numeral b.

# %%
mult_punto_punto = a*b
print("La multiplicación punto a punto de a y b es: ",mult_punto_punto)
# Out:
# La multiplicación punto a punto de a y b es:  [67.1   3.   -0.66 26.52 -6.  ]

# %% [markdown]
# d. **Construya la siguiente matriz:**
#
# A= [2 -1 -3
#
# 4 -1.5 -2.5
#
# 7.3 -0.9 -0.2]
#
# Para la construcción de una matriz es necesario escribir los componentes de cada fila separados por comas, seguidamente, cada fila debe también ser separada por comas para diferenciarse de la forma en la cual se muestra a continuación:

# %%
matriz_A = np.array([[2,-1,-3],[4,-1.5,-2.5],[7.3,-0.9,-0.2]])
print("La matriz A es: \n",matriz_A)
# Out:
# La matriz A es:
#  [[ 2.  -1.  -3. ]
#  [ 4.  -1.5 -2.5]
#  [ 7.3 -0.9 -0.2]]

# %% [markdown]
# e. **Obtenga la traspuesta de la matriz A, es decir AT**
# Para obtener la matris traspuesta de A puede implementarse la función np.transpose  o bien el comando A.T como se refleja a continuación:

# %%
print("La matriz original A es: \n", matriz_A)
traspuesta_A = np.transpose(matriz_A)
print("La traspuesta de la matriz A por método 1 es: \n",traspuesta_A)
Traspuesta_A2 = matriz_A.T
print("La traspuesta de la matriz A por método 2 es: \n",Traspuesta_A2)
# Out:
# La matriz original A es:
#  [[ 2.  -1.  -3. ]
#  [ 4.  -1.5 -2.5]
#  [ 7.3 -0.9 -0.2]]
# La traspuesta de la matriz A por método 1 es:
#  [[ 2.   4.   7.3]
#  [-1.  -1.5 -0.9]
#  [-3.  -2.5 -0.2]]
# La traspuesta de la matriz A por método 2 es:
#  [[ 2.   4.   7.3]
#  [-1.  -1.5 -0.9]
#  [-3.  -2.5 -0.2]]

# %% [markdown]
# f.**Consulte la función de los siguientes comamdos de la librería numpy: ones, round, ceil, floor. Implemente cada función para ejemplificar su uso**

# %% [markdown]
# 1.   **Función ones:** tiene como objetivo crear y devolver un array con las dimensiones especificadas cuyos elementos son todos unos (1). **Tomado de: Aprende con Alf, librería Numpy.**

# %%
vector_unos = np.ones(5)
print("El vector de unos es: ",vector_unos)

matriz_unos = np.ones((3,3))
print("La matriz de unos es: \n",matriz_unos)
# Out:
# El vector de unos es:  [1. 1. 1. 1. 1.]
# La matriz de unos es:
#  [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %% [markdown]
# 2. **Función round:** tiene como objetivo redondear el valor decimal al entero más cercano, para ello se debe especificar el objeto a redondear y la cantidad de decimales deseadas. **Tomado de: AI Planet, funciones de Python**

# %%
vector_redondear = np.array([3.2345, 5.9876, 6.341])
redondeo = np.round(vector_redondear, 1)
print("El vector redondeado es: ",redondeo)
# Out:
# El vector redondeado es:  [3.2 6.  6.3]

# %% [markdown]
# 3. **Función ceil:** es otro método para redondear objetos, este consiste en redondear cada elemento del array al estero superios cercano, es decir, aproxima hacia arriba retornando el "techo". **Tomado de: Python docs Mathematical functions**

# %%
vector_redondear = np.array([7.123, 8.567, 3.456])
redondeo_ceil = np.ceil(vector_redondear)
print("El vector redondeado con función ceil es: ",redondeo_ceil)
# Out:
# El vector redondeado con función ceil es:  [8. 9. 4.]

# %% [markdown]
# 4. **Función Floor:** realiza la tarea opuesta a la función ceil, ya que redondea hacia abajo buscando el número más cercano.

# %%
vector_floor = np.array([7.123, 8.567, 3.456])
redondeo_abajo = np.floor(vector_floor)
print("El vector redondeado con función floor es: ",redondeo_abajo)
# Out:
# El vector redondeado con función floor es:  [7. 8. 3.]

# %% [markdown]
# g. **Acceda al valor de la primera fila, tercera columna de la matriz A, e imprimalo en la consola**
#
# Para realizar este proceso se debe especificar la posición del elemento a seleccionar en la matriz dentro de corchetes []. Es importante recordar que las posiciones en Python comienzan desde 0

# %%
print("La matriz original A es: \n", matriz_A)
print("El valor de la primera fila, tercera columna de la matriz A es: ",matriz_A[0,2])
# Out:
# La matriz original A es:
#  [[ 2.  -1.  -3. ]
#  [ 4.  -1.5 -2.5]
#  [ 7.3 -0.9 -0.2]]
# El valor de la primera fila, tercera columna de la matriz A es:  -3.0

# %% [markdown]
# h. **Obtenga la segunda fila de dicha matriz, imprímalo en consola.**
#
# Para realizar esta petición se deben selecionar todas las columnas de la matriz mediante la opción ":", por otro lado se resalta que para Python las posiciones comienzan desde cero (0), por ello la fila dos se selecciona al escribir la posición uno (1).

# %%
print("La matriz original A es: \n", matriz_A)
print("La segunda fila de la matriz A es: ",matriz_A[1,:])
# Out:
# La matriz original A es:
#  [[ 2.  -1.  -3. ]
#  [ 4.  -1.5 -2.5]
#  [ 7.3 -0.9 -0.2]]
# La segunda fila de la matriz A es:  [ 4.  -1.5 -2.5]

# %% [markdown]
# i. **Consulte el comando para conocer las dimensiones de una matriz, utilícelo con la matriz e imprímalo en consola.**
#
# Para conocer las dimensiones de una matriz se puede hacer uso del comando .shape, el cual indica en uel tamaño de las filas y columnas de la matriz (en ese orden).
# Por otro lado, es posible conocer los ejes en los cuales se encuentra la matriz mediante el comando n.dim.
# Finalmente, ttambién se puede conocer el número de elementos con los que cuneta la matriz, por medio del comando .size

# %%
print("La matriz A es: \n", matriz_A)
print("Las dimensiones de la matriz A son: ",matriz_A.shape)
print("El número de ejes/dimensiones de la matriz A es: ",matriz_A.ndim)
print("El número de elementos que contiene la matriz A es: ",matriz_A.size)
# Out:
# La matriz A es:
#  [[ 2.  -1.  -3. ]
#  [ 4.  -1.5 -2.5]
#  [ 7.3 -0.9 -0.2]]
# Las dimensiones de la matriz A son:  (3, 3)
# El número de ejes/dimensiones de la matriz A es:  2
# El número de elementos que contiene la matriz A es:  9

# %% [markdown]
# j.**Construya la función y[n] = sin (pi*0.18n) en el intervalo 0<= n <=80**
#
# En este caso se debe crear un rango de datos que vaya desde 0 hasta 80, (se aclara que se debe ir hasta la posición 81 ya que Python no abarca el último valor asignado), este intervalo se construye mediante la función np.arange.
# Postriormente se llama al número pi y a la función seno propias de Numpy para construir la función.
#
# La función y[n] puede ser observada mediante un gráfico en el tiempo construido por medio de la librería Matplotlib.

# %%
y = np.sin(pi*0.18*np.arange(0,81))
print("La función y es: ",y)
plt.plot(np.arange(0,81),y, label='Función seno')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.title('Función seno')
plt.legend()
plt.show()
# Out:
# La función y es:  [ 0.00000000e+00  5.35826795e-01  9.04827052e-01  9.92114701e-01
#   7.70513243e-01  3.09016994e-01 -2.48689887e-01 -7.28968627e-01
#  -9.82287251e-01 -9.29776486e-01 -5.87785252e-01 -6.27905195e-02
#   4.81753674e-01  8.76306680e-01  9.98026728e-01  8.09016994e-01
#   3.68124553e-01 -1.87381315e-01 -6.84547106e-01 -9.68583161e-01
#  -9.51056516e-01 -6.37423990e-01 -1.25333234e-01  4.25779292e-01
#   8.44327926e-01  1.00000000e+00  8.44327926e-01  4.25779292e-01
#  -1.25333234e-01 -6.37423990e-01 -9.51056516e-01 -9.68583161e-01
#  -6.84547106e-01 -1.87381315e-01  3.68124553e-01  8.09016994e-01
#   9.98026728e-01  8.76306680e-01  4.81753674e-01 -6.27905195e-02
#  -5.87785252e-01 -9.29776486e-01 -9.82287251e-01 -7.28968627e-01
#  -2.48689887e-01  3.09016994e-01  7.70513243e-01  9.92114701e-01
#   9.04827052e-01  5.35826795e-01  1.10218212e-15 -5.35826795e-01
#  -9.04827052e-01 -9.92114701e-01 -7.70513243e-01 -3.09016994e-01
# ...

# %% [markdown]
# k. **Construya otra senosoidal y2[n] = cos(2pi*0.03n)**
#
# De forma similar al ejercicio j, se plantea el rango de la función mediante np.arange, para abarcar el espacio de 0 a 80. Consecuentemente se llama la función coseno y pi de numpy. Este resultado puede observarse en un gráfico mediante la librería Matplotlib

# %%
y2 = np.cos(2*pi*0.03*np.arange(0,81))
print("La función y2 es: ",y2)

plt.plot(np.arange(0,81),y2, label='Función coseno', color='orange')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.title('Función coseno')
plt.legend()
plt.show()
# Out:
# La función y2 es:  [ 1.00000000e+00  9.82287251e-01  9.29776486e-01  8.44327926e-01
#   7.28968627e-01  5.87785252e-01  4.25779292e-01  2.48689887e-01
#   6.27905195e-02 -1.25333234e-01 -3.09016994e-01 -4.81753674e-01
#  -6.37423990e-01 -7.70513243e-01 -8.76306680e-01 -9.51056516e-01
#  -9.92114701e-01 -9.98026728e-01 -9.68583161e-01 -9.04827052e-01
#  -8.09016994e-01 -6.84547106e-01 -5.35826795e-01 -3.68124553e-01
#  -1.87381315e-01 -1.83697020e-16  1.87381315e-01  3.68124553e-01
#   5.35826795e-01  6.84547106e-01  8.09016994e-01  9.04827052e-01
#   9.68583161e-01  9.98026728e-01  9.92114701e-01  9.51056516e-01
#   8.76306680e-01  7.70513243e-01  6.37423990e-01  4.81753674e-01
#   3.09016994e-01  1.25333234e-01 -6.27905195e-02 -2.48689887e-01
#  -4.25779292e-01 -5.87785252e-01 -7.28968627e-01 -8.44327926e-01
#  -9.29776486e-01 -9.82287251e-01 -1.00000000e+00 -9.82287251e-01
#  -9.29776486e-01 -8.44327926e-01 -7.28968627e-01 -5.87785252e-01
# ...

# %% [markdown]
# j.**Genere una señal que sea la suma de estas dos señales, es s[n]= y[n]+y2[n] y una cuarta que sea el producto de estas, t[n]= y[n].y2[n]**
#
# A través del uso de comandos básicos (+,*) se puede obtener la suma y el producto de ambas funciones y, y2.

# %%
s = y+y2
print("La suma de las señales y + y2= s[n] es: ",s)

plt.plot(np.arange(0,81),s, label='Suma de señales, S', color='green')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.title('Suma de señales')
plt.legend()
plt.show()

t = y*y2
print("La señal t es: ",t)

plt.plot(np.arange(0,81),t, label='Producto de señales, T', color='red')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.title('Producto de señales')
plt.legend()
plt.show
# Out:
# La suma de las señales y + y2= s[n] es:  [ 1.          1.51811405  1.83460354  1.83644263  1.49948187  0.89680225
#   0.1770894  -0.48027874 -0.91949673 -1.05510972 -0.89680225 -0.54454419
#  -0.15567032  0.10579344  0.12172005 -0.14203952 -0.62399015 -1.18540804
#  -1.65313027 -1.87341021 -1.76007351 -1.3219711  -0.66116003  0.05765474
#   0.65694661  1.          1.03170924  0.79390384  0.41049356  0.04712312
#  -0.14203952 -0.06375611  0.28403606  0.81064541  1.36023925  1.76007351
#   1.87433341  1.64681992  1.11917766  0.41896315 -0.27876826 -0.80444325
#  -1.04507777 -0.97765851 -0.67446918 -0.27876826  0.04154462  0.14778678
#  -0.02494943 -0.44646046 -1.         -1.51811405 -1.83460354 -1.83644263
#  -1.49948187 -0.89680225 -0.1770894   0.48027874  0.91949673  1.05510972
#   0.89680225  0.54454419  0.15567032 -0.10579344 -0.12172005  0.14203952
#   0.62399015  1.18540804  1.65313027  1.87341021  1.76007351  1.3219711
# ...

# %% [markdown]
# m. **Graficar en la misma figura las señales y[n] y y2[n], utilice leyenda y colores diferentes para cada señal. Asigne título a cada eje**

# %%
plt.plot(np.arange(0,81),y, label='Funcion seno', color='blue')
plt.plot(np.arange(0,81),y2, label='funcion coseno', color='orange')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.title('Funciones seno y coseno')
plt.legend()
plt.show()

# %% [markdown]
# n.**Graficar en la misma figura las señales s[n] y t[n], utilice leyenda y colores diferentes para cada señal. Asigne título a cada eje**

# %%
plt.plot(np.arange(0,81),s, label='Suma de señales, S', color='green')
plt.plot(np.arange(0,81),t, label='Producto de señales, T', color='red')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.title('Suma y producto de señales y, y2')
plt.legend()
plt.show()

# %% [markdown]
# **RETO**
#
# Escribir una función que reciba un diccionario con las notas de los alumnos de un curso y devuelva una serie con la nota mínima, la máxima, media y  la desviación típica.
#
# **Solución**
# Para especificar el reto se elaboró un diccionario que contiene las notas finales de 5 alumnos, una vez construido, se enviaron los datos a la función evaluar_notas en la cual se convirtió el diccionario a una serie con el objetivo de realizar sus respectivos cálculos estadísticos, donde por medio de la función **.min** se calcula el mínimo de un arreglo de números, con **.max** se evalua el máximo entre un conjunto de elementos, con **.mean** se encuentra el valor medio de los datos y finalmente con la función **.std** se plantea la desviación de los valores.
# Una vez calculadas las estadístivas se retornan como otro arreglo unidimensional (serie), para luego ser mostrados en consola.

# %%
def evaluar_notas(diccionario_estudiantes):
    serie = pd.Series(diccionario_estudiantes)
    minimo = serie.min()
    maximo = serie.max()
    media = serie.mean()
    desviacion = serie.std()
    return pd.Series([minimo, maximo, media, desviacion], index=['minimo', 'maximo', 'media', 'desviacion'])

# %%
diccionario_estudiantes = {
        'Estudiante 1': 3.5,
        'Estudiante 2': 4.0,
        'Estudiante 3': 2.5,
        'Estudiante 4': 4.5,
        'Estudiante 5': 3.0
}

notas_estudiantes = evaluar_notas(diccionario_estudiantes)
print(notas_estudiantes)
# Out:
# minimo        2.500000
# maximo        4.500000
# media         3.500000
# desviacion    0.790569
# dtype: float64
